# %%
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt

# %%
# Step 1: Sample Data & Mean

data = np.array([1050, 1070, 1065, 1080, 1045, 1075, 1060, 1070])
n = len(data)

sample_mean = np.mean(data)

print("Sample Data:", data)
print("Sample Size (n):", n)
print("Sample Mean (x̄):", sample_mean)
# Out:
# Sample Data: [1050 1070 1065 1080 1045 1075 1060 1070]
# Sample Size (n): 8
# Sample Mean (x̄): 1064.375

# %%
# Step 2: Sample Standard Deviation

sample_variance = np.var(data, ddof=1)
sample_std_dev = np.sqrt(sample_variance)

print("\nSample Variance (s²):", sample_variance)
print("Sample Standard Deviation (s):", sample_std_dev)
# Out:
# Sample Variance (s²): 145.98214285714286
# Sample Standard Deviation (s): 12.08230701716948

# %%
# Step 3: 95% Confidence Interval + Boxplot

t_critical = 2.365  # for df = 7
standard_error = sample_std_dev / sqrt(n)
margin_of_error = t_critical * standard_error

ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

sample_median = np.median(data)

plt.figure(figsize=(8, 5))

plt.boxplot(
    data,
    vert=False,
    showmeans=True,
    meanprops=dict(marker='o', markerfacecolor='red', markersize=8)
)

plt.hlines(
    y=1,
    xmin=ci_lower,
    xmax=ci_upper,
    colors='blue',
    linewidth=3,
    label='95% Confidence Interval'
)

plt.scatter(sample_median, 1, color='green', zorder=3, label='Median')

plt.title("Boxplot 95% Confidence Interval")
plt.xlabel("Value")
plt.yticks([])

plt.legend()
plt.savefig("Figure4",dpi=1000)
plt.tight_layout()
plt.show()

print("\n95% Confidence Interval:")
print(f"Lower Bound: {ci_lower:.2f}")
print(f"Upper Bound: {ci_upper:.2f}")
# Out:
# 95% Confidence Interval:
# Lower Bound: 1054.27
# Upper Bound: 1074.48

# %%
# Step 4: Interpretation Output

print("\nInterpretation:")
print("We are 95% confident that the true population mean lies within this interval.")
# Out:
# Interpretation:
# We are 95% confident that the true population mean lies within this interval.
